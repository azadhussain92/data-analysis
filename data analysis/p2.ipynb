# %% [markdown]
# # series

# %%
import pandas as pd

# %%
l = ['red','green','blue']
color = pd.Series(l)

# %%
print(color)
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: str

# %% [markdown]
# # DataFrame

# %%
d = {"id":[1,2,3],
     'num':["abc","xyz","yub"],
     'sal':[500,600,700]
     }
df = pd.DataFrame(d)
df
# Out:
#    id  num  sal
# 0   1  abc  500
# 1   2  xyz  600
# 2   3  yub  700

# %%
import pandas as pd

# %%
data = ['01-jan-2002','03-feb-2004','04-jun-2003']
s = pd.Series(data)
# pd.to_datetime(s, errors='coerce')
pd.to_datetime(s)
# Out:
# C:\Users\azadh\AppData\Local\Temp\ipykernel_6044\3256416468.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(s)
# 0   2002-01-01
# 1   2004-02-03
# 2   2003-06-04
# dtype: datetime64[us]

# %%
d = {
    'date': ['01-jan-2002','03-feb-2004','04-jun-2003', '2002-01-01', '2004-02-03', '2003-06-04']
}

df1 = pd.DataFrame(d)
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6 non-null      str
# dtypes: str(1)
# memory usage: 176.0 bytes

# %%
pd.to_datetime(df1['date'], errors='coerce')
# Out:
# C:\Users\azadh\AppData\Local\Temp\ipykernel_6044\358892004.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df1['date'], errors='coerce')
# 0   2002-01-01
# 1   2004-02-03
# 2   2003-06-04
# 3   2002-01-01
# 4   2004-02-03
# 5   2003-06-04
# Name: date, dtype: datetime64[us]

# %%
pd.to_datetime(data)
# Out:
# C:\Users\azadh\AppData\Local\Temp\ipykernel_6044\3022737544.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(data)
# DatetimeIndex(['2002-01-01', '2004-02-03', '2003-06-04'], dtype='datetime64[us]', freq=None)

# %%
d = {
    'rs': ['2.5', '4.7', 'A', '4.9']
}

azad = pd.DataFrame(d)
azad.info()
azad
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rs      4 non-null      str
# dtypes: str(1)
# memory usage: 160.0 bytes
#     rs
# 0  2.5
# 1  4.7
# 2    A
# 3  4.9

# %%
azad['rs'] = azad['rs'].astype('float', errors='ignore')

# %%
azad['rs1'] = pd.to_numeric(azad['rs'], errors='coerce')

# %%
# azad['rs'].info()
print(azad['rs'])
# Out:
# 0    2.5
# 1    4.7
# 2      A
# 3    4.9
# Name: rs, dtype: str

# %%
azad['rs1'].info()
azad['rs1']
# Out:
# <class 'pandas.Series'>
# RangeIndex: 4 entries, 0 to 3
# Series name: rs1
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      float64
# dtypes: float64(1)
# memory usage: 160.0 bytes
# 0    2.5
# 1    4.7
# 2    NaN
# 3    4.9
# Name: rs1, dtype: float64

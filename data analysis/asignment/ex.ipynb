# %%
import pandas as pd
data = ['01-jan-2002', '10-mar-2004', '03-jun-2005', 'abc']
s = pd.Series(data)

pd.to_datetime(s, errors='coerce')
# Out:
# C:\Users\azadh\AppData\Local\Temp\ipykernel_5296\4184236304.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(s, errors='coerce')
# 0   2002-01-01
# 1   2004-03-10
# 2   2005-06-03
# 3          NaT
# dtype: datetime64[us]

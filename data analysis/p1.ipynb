# %%
print("data analysis")
# Out:
# data analysis

# %%
a=2    
b= 3
c= a+b
print(c)
# Out:
# 5

# %%
import pandas

# %%
pandas.__version__
# Out:
# '3.0.2'

# %%
import pandas as pd

# %%
a =10
b = 20

# %%
a+b
a-b
a*b
# Out:
# 200

# %%
print(a+b)
print(a-b)
a*b
# Out:
# 30
# -10
# 200
